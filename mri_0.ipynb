# %%
# -*- coding: utf-8 -*-
import numpy as np
import pydicom
import cv2
import PIL
import matplotlib.pyplot as plt

# %%
import os

# %%
import pandas as pd

# %%
path1 = "D:\\Uni\\mri\\SK_MRI\\MS_dataset_full\\MS"

# %%
path2 = "\\01_32\\01_320015.tif"

# %%
path3 = "\\01_32"

# %%
path4 = "\\IM000015"

# %%
mask = np.array(PIL.Image.open(path1 + path2))

# %%
plt.imshow(mask, cmap = 'gray')

# %%
ds = pydicom.dcmread(path1 + path3 + path4)

# %%
mat = ds.pixel_array

# %%
plt.imshow(mat, cmap = 'gray')

# %%
folder = "D:/Uni/mri/SK_MRI/MS_dataset_full/MS/01_1/"

# %%
tree_im = sorted([folder+file for file in next(os.walk(folder))[-1] if len(file.split(".")) < 2])

# %%
tree_mask = sorted([folder+file for file in next(os.walk(folder))[-1] if len(file.split(".")) > 1])

# %%
fig = plt.figure(figsize = (20, 20), dpi= 80)
images_slices = []
for i, file in enumerate(tree_im):
    sub1 = len(tree_im)
    plt.subplot(sub1//5+1, 5, i+1)
    image = pydicom.dcmread(file).pixel_array
    plt.imshow(image, cmap = 'gray')
    images_slices.append(image)
plt.show()

# %%
images_slices = np.array(images_slices)

# %%
fig = plt.figure(figsize = (20, 20), dpi = 80)
for i, file in enumerate(tree_mask):
    sub1 = len(tree_im)
    plt.subplot(sub1//5+1, 5, i+1)
    mask = np.array(PIL.Image.open(file))
    plt.imshow(mask, cmap = 'gray')

plt.show()

# %%
df = pd.read_csv('reports.csv', sep='|')

# %%
data = df[df['label'] == 'ms']['id']

# %%
for d in data:
    try:
        folder = "D:/Uni/mri/SK_MRI/MS_dataset_full/MS//"
        print(d)
        tree_im = sorted([folder+file for file in next(os.walk(folder))[-1] if len(file.split(".")) < 2])
        print('1')
        images_slices = []
        print('2')
        for i, file in enumerate(tree_im):
            image = pydicom.dcmread(file).pixel_array
        print('3')
        images_slices = np.array(images_slices)
        print('4')
        files = sorted([file for file in next(os.walk(folder))[-1] if len(file.split(".")) < 2])
        print('5')
        for f in files:
            brain = pydicom.dcmread(folder+f).pixel_array
            print('6')
            plt.imsave(folder + f + ".png", brain, cmap='gray')
            print('7')
    except:
        print('8')
        pass
# Out:
# 01_414
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 01_344
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 01_316
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 01_294
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 01_196
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# ...
